# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
df=pd.read_csv(r"C:\Users\Shwet\OneDrive\Desktop\Python\edit _homeprices.csv")
df
# Out:
#     area  bedrooms   price  age
# 0   1056         2   39.07   24
# 1   2600         4  120.00   26
# 2   1440         3   62.00   25
# 3   1521         3   75.00   27
# 4   1200         2   51.00   28
# 5   1170         2   38.00   29
# 6   2732         4  135.00   30
# 7   3300         4  155.00   31
# 8   1310         3   50.00   33
# 9   3700         5  167.00   25
# 10  1800         3   82.00   28
# 11  2785         4  140.00   34
# 12  1000         2   38.00   35
# 13  1100         2   40.00   38
# 14  2250         3  101.00   22
# 15  1175         2   42.00   26
# 16  1180         3   48.00   37
# 17  1540         3   60.00   30
# 18  2770         3  102.00   30
# 19   800         1   32.00   33

# %%
df=pd.read_csv(r"C:\Users\Shwet\OneDrive\Desktop\Python\edit _homeprices.csv")
df.describe()
# Out:
#               area   bedrooms       price        age
# count    20.000000  20.000000   20.000000  20.000000
# mean   1821.450000   2.900000   78.853500  29.550000
# std     864.615794   0.967906   43.761901   4.406634
# min     800.000000   1.000000   32.000000  22.000000
# 25%    1173.750000   2.000000   41.500000  26.000000
# 50%    1480.500000   3.000000   61.000000  29.500000
# 75%    2633.000000   3.250000  106.500000  33.000000
# max    3700.000000   5.000000  167.000000  38.000000

# %%
x=df.area
x
# Out:
# 0     1056
# 1     2600
# 2     1440
# 3     1521
# 4     1200
# 5     1170
# 6     2732
# 7     3300
# 8     1310
# 9     3700
# 10    1800
# 11    2785
# 12    1000
# 13    1100
# 14    2250
# 15    1175
# 16    1180
# 17    1540
# 18    2770
# 19     800
# Name: area, dtype: int64

# %%
x=df.drop(columns=['price'])
print(x)
y=df.drop(columns=['area','bedrooms','age'])
print(y)
print(x.ndim)
print(y.ndim)
# Out:
#     area  bedrooms  age
# 0   1056         2   24
# 1   2600         4   26
# 2   1440         3   25
# 3   1521         3   27
# 4   1200         2   28
# 5   1170         2   29
# 6   2732         4   30
# 7   3300         4   31
# 8   1310         3   33
# 9   3700         5   25
# 10  1800         3   28
# 11  2785         4   34
# 12  1000         2   35
# 13  1100         2   38
# 14  2250         3   22
# 15  1175         2   26
# 16  1180         3   37
# 17  1540         3   30
# 18  2770         3   30
# 19   800         1   33
#      price
# 0    39.07
# 1   120.00
# 2    62.00
# 3    75.00
# 4    51.00
# 5    38.00
# 6   135.00
# 7   155.00
# 8    50.00
# 9   167.00
# 10   82.00
# 11  140.00
# 12   38.00
# 13   40.00
# 14  101.00
# 15   42.00
# 16   48.00
# 17   60.00
# 18  102.00
# 19   32.00
# 2
# 2

# %%
x=df.drop(columns=['price'])
y=df.drop(columns=['area','bedrooms','age'])
print(x.ndim)
print(y.ndim)
# Out:
# 2
# 2

# %%
model=linear_model.LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
sqft=int(input("Enter sqft:"))
bed=int(input("Enter no of Bedrooms:"))
age=int(input("Enter age:"))
amount=model.predict([[sqft,bed,age]])
print("The assessed value for the house with ",sqft,"Sqft is :Rs.",amount[0][0])
# Out:
# Enter sqft: 6000
# Enter no of Bedrooms: 6
# Enter age: 25
# The assessed value for the house with  6000 Sqft is :Rs. 279.5548133573252
# C:\Users\Shwet\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model.coef_
# Out:
# array([[0.0430473 , 6.79743469, 0.05407584]])

# %%
model.intercept_
# Out:
# array([-20.86551292])

# %%
plt.scatter(df.area,df.price,color="g",marker="D")
plt.plot(df.area,model.predict(df[['area','bedrooms','age']]))
